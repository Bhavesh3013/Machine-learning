# %% [markdown]
# #sampling
#
#
# *   Random sampling : Probability is also known as random sampling
# *   Why random sampling is also known as probability sampling?\
#       each element in the population has an equal chance of being selected or known probaibilty of being selected (Stratified random sampling)
#
#
# 2.  Stratified Random Sampling
#
# the population is divided into the groups of strata. A random sample is selected from each stratum based upon the percentage that each subgroup represents popu;ation. Stratified random samples are genrally more acc inrepresentiong population than random samples
#
# 3.  Convinience Sampling:\
#       Convinience samples are nonprobabiltiy samples. Therefore it is not possible to specify the probabilty of any population elements being selected for the sample. indeed, it is not possible to specify the populaiton from which the sample was drawn.
#
# 4.  Quota Sampling:\
#
# | Technique | Example |
# | ------------| --------|
# | Simple Random Sampling     | the names of all thousands childresn are into computer database the computer is then instrutced to random select 100 names|
#  these children and their parents are then contacted |
# | Stratified random sampling     | The names of all 1000 children are placed into a computer database and then organized by grade the computer then instructed randomly select 35 names from rach of these grades|
# | Convinience Sampling     | The researcher knows middle school teachers and the teacher volunteer per 35 students for the study |
# | Quota Sampling | Use in the middle school directry the researcher selects first 20 6th grade boys |
#
#
# If we are representing population descriptive ststistics we represent it as greek aplhabets (Σ,σ)\
# If we represents sample descriptive stats we represent it by small letters
# 1. Determine the populations size ℕ
# 2. Determine the sample size n
# 3. No each member of the population under investigation in serail order. Suppose there are 100 members them from 00 to 99.
# 4. Determine the starting point of selecting sample by randomly picking up a page from number tables and dropping your finger in the page blindly.
# 5. Choose the direction in which you want to read the nos (left to right)
# 6. Select the 1st 'n' number whose X digits are between 0 to ℕ. if ℕ =100 then x would be 2 if ℕ is a four digit number then would be 3 and so on.
#
# | Urban |         Rural |
# |-------| -------|
# | Male | Female | Male | Female|
# | 65% | 35%| 55% | 45% |
#
#
# **Disproportionate Stratified Sample**
# Suppose in our ex of urban/rural and male/female stratum pop, the stratum estimated estimated variance σ^2\
#
# | Stratum | Estimated Variance (σ^2) | Standard Deviation (σ) |
# |---|---|---|
# | Urban Male | 3.0 | 1.73 |
# | Urban Female | 5.5 | 2.35 |
# | Rural Male | 2.5 | 1.58 |
# | Rural Female | 1.75 | 1.32 |
#
#
#
# Standard deviation
# it is a kind of average of the absolute μ
#
# The average distance of data points from =
#
#
# Kurtosis : Flatness of the curve
# skewness :
