# %%
import pandas as pd
df = pd.read_csv('/content/NIFTY 50_Historical_PR_06072023to09072024.csv')
df.head()
# Out:
#   Index Name         Date      Open      High       Low     Close
# 0   NIFTY 50  09 Jul 2024  24351.00  24443.60  24331.90  24433.20
# 1   NIFTY 50  08 Jul 2024  24329.45  24344.60  24240.55  24320.55
# 2   NIFTY 50  05 Jul 2024  24213.35  24363.00  24168.85  24323.85
# 3   NIFTY 50  04 Jul 2024  24369.95  24401.00  24281.00  24302.15
# 4   NIFTY 50  03 Jul 2024  24291.75  24309.15  24207.10  24286.50
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Low'].plot(kind='hist', bins=20, title='Low')
# ...

# %%
df.isnull().sum()
# Out:
# Index Name    0
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# dtype: int64
